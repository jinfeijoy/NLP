# %%
import sys
import os
sys.path.append('C:\\Users\\luoyan011\\Desktop\\PersonalLearning\\GitHub\\python_functions\\jl_nlp_pkg')
sys.path.append('C:\\Users\\luoyan011\\Desktop\\PersonalLearning\\GitHub\\python_functions\\jl_model_explain_pkg')
import nlpbasic.textClean as textClean
import nlpbasic.docVectors as DocVector
import nlpbasic.dataExploration as DataExploration
import nlpbasic.lda as lda
import nlpbasic.tfidf as tfidf
import nlpbasic.text_summarize as txtsmr
import nlpbasic.word_embedding as wdembd

import model_explain.plot as meplot
import model_explain.shap as meshap

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np
import re
import seaborn as sns

import nltk
from nltk.chunk import conlltags2tree, tree2conlltags
from pprint import pprint

datapath = 'C:\\Users\\luoyan011\\Desktop\\PersonalLearning\\GitHub\\NLP_data'

# %%
data = pd.read_csv(os.path.join(datapath,'ner_dataset.csv'), encoding= 'unicode_escape')
data.columns = ['sentence', 'word', 'pos', 'tag']
data.ffill(inplace=True)
data.head()
# Out:
#       sentence           word  pos tag
# 0  Sentence: 1      Thousands  NNS   O
# 1  Sentence: 1             of   IN   O
# 2  Sentence: 1  demonstrators  NNS   O
# 3  Sentence: 1           have  VBP   O
# 4  Sentence: 1        marched  VBN   O

# %%
import json
from collections import defaultdict

def pop_annot(raw_line):
    in_line = defaultdict(list, **raw_line)
    if 'annotation' in in_line:
        labels = in_line['annotation']
        for c_lab in labels:
            if len(c_lab['label'])>0:
                in_line[c_lab['label'][0]] += c_lab['points']
    return in_line
with open(os.path.join(datapath, 'Entity Recognition in Resumes.json'), encoding="utf8") as f:
    # data is jsonl and so we parse it line-by-line
    resume_data = [json.loads(f_line) for f_line in f.readlines()]
    resume_df = pd.DataFrame([pop_annot(line) for line in resume_data])
    
for col in resume_df.columns:
    print(col)
    display(resume_df.iloc[0][col])
    
displacy.render(nlp(resume_df.iloc[0]['content']), jupyter=True, style='ent')
# Out:
# content
# "Abhishek Jha\nApplication Development Associate - Accenture\n\nBengaluru, Karnataka - Email me on Indeed: indeed.com/r/Abhishek-Jha/10e7a8cb732bc43a\n\n• To work for an organization which provides me the opportunity to improve my skills\nand knowledge for my individual and company's growth in best possible ways.\n\nWilling to relocate to: Bangalore, Karnataka\n\nWORK EXPERIENCE\n\nApplication Development Associate\n\nAccenture -\n\nNovember 2017 to Present\n\nRole: Currently working on Chat-bot. Developing Backend Oracle PeopleSoft Queries\nfor the Bot which will be triggered based on given input. Also, Training the bot for different possible\nutterances (Both positive and negative), which will be given as\ninput by the user.\n\nEDUCATION\n\nB.E in Information science and engineering\n\nB.v.b college of engineering and technology -  Hubli, Karnataka\n\nAugust 2013 to June 2017\n\n12th in Mathematics\n\nWoodbine modern school\n\nApril 2011 to March 2013\n\n10th\n\nKendriya Vidyalaya\n\nApril 2001 to March 2011\n\nSKILLS\n\nC (Less than 1 year), Database (Less than 1 year), Database Management (Less than 1 year),\nDatabase Management System (Less than 1 year), Java (Less than 1 year)\n\nADDITIONAL INFORMATION\n\nTechnical Skills\n\nhttps://www.indeed.com/r/Abhishek-Jha/10e7a8cb732bc43a?isid=rex-download&ikw=download-top&co=IN\n\n\n• Programming language: C, C++, Java\n• Oracle PeopleSoft\n• Internet Of Things\n• Machine Learning\n• Database Management System\n• Computer Networks\n• Operating System worked on: Linux, Windows, Mac\n\nNon - Technical Skills\n\n• Honest and Hard-Working\n• Tolerant and Flexible to Different Situations\n• Polite and Calm\n• Team-Player"
# annotation
# [{'label': ['Skills'],
#   'points': [{'start': 1295,
#     'end': 1621,
#     'text': '\n• Programming language: C, C++, Java\n• Oracle PeopleSoft\n• Internet Of Things\n• Machine Learning\n• Database Management System\n• Computer Networks\n• Operating System worked on: Linux, Windows, Mac\n\nNon - Technical Skills\n\n• Honest and Hard-Working\n• Tolerant and Flexible to Different Situations\n• Polite and Calm\n• Team-Player'}]},
#  {'label': ['Skills'],
#   'points': [{'start': 993,
#     'end': 1153,
#     'text': 'C (Less than 1 year), Database (Less than 1 year), Database Management (Less than 1 year),\nDatabase Management System (Less than 1 year), Java (Less than 1 year)'}]},
#  {'label': ['College Name'],
#   'points': [{'start': 939, 'end': 956, 'text': 'Kendriya Vidyalaya'}]},
#  {'label': ['College Name'],
#   'points': [{'start': 883, 'end': 904, 'text': 'Woodbine modern school'}]},
#  {'label': ['Graduation Year'],
#   'points': [{'start': 856, 'end': 860, 'text': '2017\n'}]},
#  {'label': ['College Name'],
#   'points': [{'start': 771,
#     'end': 813,
#     'text': 'B.v.b college of engineering and technology'}]},
#  {'label': ['Designation'],
#   'points': [{'start': 727,
#     'end': 769,
#     'text': 'B.E in Information science and engineering\n'}]},
#  {'label': ['Companies worked at'],
#   'points': [{'start': 407, 'end': 415, 'text': 'Accenture'}]},
#  {'label': ['Designation'],
#   'points': [{'start': 372,
#     'end': 404,
#     'text': 'Application Development Associate'}]},
#  {'label': ['Email Address'],
#   'points': [{'start': 95,
#     'end': 145,
#     'text': 'Indeed: indeed.com/r/Abhishek-Jha/10e7a8cb732bc43a\n'}]},
#  {'label': ['Location'],
#   'points': [{'start': 60, 'end': 68, 'text': 'Bengaluru'}]},
#  {'label': ['Companies worked at'],
#   'points': [{'start': 49, 'end': 57, 'text': 'Accenture'}]},
#  {'label': ['Designation'],
#   'points': [{'start': 13,
#     'end': 45,
#     'text': 'Application Development Associate'}]},
#  {'label': ['Name'],
#   'points': [{'start': 0, 'end': 11, 'text': 'Abhishek Jha'}]}]
# extras
# None
# Skills
# [{'start': 1295,
#   'end': 1621,
#   'text': '\n• Programming language: C, C++, Java\n• Oracle PeopleSoft\n• Internet Of Things\n• Machine Learning\n• Database Management System\n• Computer Networks\n• Operating System worked on: Linux, Windows, Mac\n\nNon - Technical Skills\n\n• Honest and Hard-Working\n• Tolerant and Flexible to Different Situations\n• Polite and Calm\n• Team-Player'},
#  {'start': 993,
#   'end': 1153,
#   'text': 'C (Less than 1 year), Database (Less than 1 year), Database Management (Less than 1 year),\nDatabase Management System (Less than 1 year), Java (Less than 1 year)'}]
# College Name
# [{'start': 939, 'end': 956, 'text': 'Kendriya Vidyalaya'},
#  {'start': 883, 'end': 904, 'text': 'Woodbine modern school'},
#  {'start': 771,
#   'end': 813,
#   'text': 'B.v.b college of engineering and technology'}]
# Graduation Year
# [{'start': 856, 'end': 860, 'text': '2017\n'}]
# Designation
# [{'start': 727,
#   'end': 769,
#   'text': 'B.E in Information science and engineering\n'},
#  {'start': 372, 'end': 404, 'text': 'Application Development Associate'},
#  {'start': 13, 'end': 45, 'text': 'Application Development Associate'}]
# Companies worked at
# [{'start': 407, 'end': 415, 'text': 'Accenture'},
#  {'start': 49, 'end': 57, 'text': 'Accenture'}]
# Email Address
# [{'start': 95,
#   'end': 145,
#   'text': 'Indeed: indeed.com/r/Abhishek-Jha/10e7a8cb732bc43a\n'}]
# Location
# [{'start': 60, 'end': 68, 'text': 'Bengaluru'}]
# Name
# [{'start': 0, 'end': 11, 'text': 'Abhishek Jha'}]
# Degree
# nan
# Years of Experience
# nan
# UNKNOWN
# nan
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Abhishek Jha
# Application Development Associate - Accenture
#
# Bengaluru
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Karnataka - Email
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  me on Indeed: indeed.com/r/Abhishek-Jha/10e7a8cb732bc43a</br></br>• To work for an organization which provides me the opportunity to improve my skills</br>and knowledge for my individual and company's growth in best possible ways.</br></br>Willing to relocate to: Bangalore,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Karnataka
#
# WORK EXPERIENCE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br></br>Application Development Associate</br></br>Accenture -</br></br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     November 2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  to Present</br></br>Role: Currently working on Chat-bot. Developing Backend Oracle PeopleSoft Queries</br>for the Bot which will be triggered based on given input. Also, Training the bot for different possible</br>utterances (Both positive and negative), which will be given as</br>input by the user.</br></br>EDUCATION</br></br>B.E in Information science and engineering</br></br>B.v.b college of engineering and technology -
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hubli
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Karnataka
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br></br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     August 2013 to June 2017
#
# 12th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  in Mathematics</br></br>Woodbine modern school</br></br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April 2011 to March 2013
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br></br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# </br></br>Kendriya Vidyalaya</br></br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April 2001 to March 2011
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br></br>SKILLS</br></br>C (
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Less than 1 year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ), Database (
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Less than 1 year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ),
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Database Management
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Less than 1 year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ),</br>Database Management System (
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Less than 1 year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ),
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Java
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Less than 1 year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# )</br></br>ADDITIONAL INFORMATION</br></br>Technical Skills</br></br>https://www.indeed.com/r/Abhishek-Jha/10e7a8cb732bc43a?isid=rex-download&amp;ikw=download-top&amp;co=IN</br></br></br>• Programming language: C,
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     C++
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# , Java</br>• Oracle PeopleSoft</br>• Internet Of Things</br>• Machine Learning</br>• Database Management System</br>• Computer Networks</br>• Operating System worked on: Linux, Windows, Mac</br></br>Non - Technical Skills</br></br>• Honest and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hard-Working
# •
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Tolerant and Flexible to Different Situations</br>• Polite and Calm</br>• Team-Player</div></span>

# %%
def preprocess(sent):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent
tree2conlltags(preprocess(resume_df.iloc[0]['content']))
# Out:
# [('Abhishek', 'NNP', 'O'),
#  ('Jha', 'NNP', 'O'),
#  ('Application', 'NNP', 'O'),
#  ('Development', 'NNP', 'O'),
#  ('Associate', 'NNP', 'O'),
#  ('-', ':', 'O'),
#  ('Accenture', 'NN', 'O'),
#  ('Bengaluru', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('Karnataka', 'NNP', 'O'),
#  ('-', ':', 'O'),
#  ('Email', 'NNP', 'O'),
#  ('me', 'PRP', 'O'),
#  ('on', 'IN', 'O'),
#  ('Indeed', 'RB', 'O'),
#  (':', ':', 'O'),
#  ('indeed.com/r/Abhishek-Jha/10e7a8cb732bc43a', 'JJ', 'O'),
#  ('•', 'NN', 'O'),
#  ('To', 'TO', 'O'),
#  ('work', 'VB', 'O'),
#  ('for', 'IN', 'O'),
#  ('an', 'DT', 'O'),
#  ('organization', 'NN', 'O'),
#  ('which', 'WDT', 'O'),
#  ('provides', 'VBZ', 'O'),
#  ('me', 'PRP', 'O'),
#  ('the', 'DT', 'O'),
#  ('opportunity', 'NN', 'O'),
#  ('to', 'TO', 'O'),
#  ('improve', 'VB', 'O'),
#  ('my', 'PRP$', 'O'),
#  ('skills', 'NNS', 'O'),
#  ('and', 'CC', 'O'),
#  ('knowledge', 'NN', 'O'),
#  ('for', 'IN', 'O'),
#  ('my', 'PRP$', 'O'),
#  ('individual', 'JJ', 'O'),
#  ('and', 'CC', 'O'),
#  ('company', 'NN', 'O'),
#  ("'s", 'POS', 'O'),
#  ('growth', 'NN', 'O'),
#  ('in', 'IN', 'O'),
#  ('best', 'JJS', 'O'),
#  ('possible', 'JJ', 'O'),
#  ('ways', 'NNS', 'O'),
#  ('.', '.', 'O'),
#  ('Willing', 'VBG', 'O'),
#  ('to', 'TO', 'O'),
#  ('relocate', 'VB', 'O'),
#  ('to', 'TO', 'O'),
#  (':', ':', 'O'),
#  ('Bangalore', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('Karnataka', 'NNP', 'O'),
#  ('WORK', 'NNP', 'O'),
#  ('EXPERIENCE', 'NNP', 'O'),
#  ('Application', 'NNP', 'O'),
#  ('Development', 'NNP', 'O'),
#  ('Associate', 'NNP', 'O'),
#  ('Accenture', 'NNP', 'O'),
#  ('-', ':', 'O'),
#  ('November', 'NNP', 'O'),
#  ('2017', 'CD', 'O'),
#  ('to', 'TO', 'O'),
#  ('Present', 'NNP', 'O'),
#  ('Role', 'NNP', 'O'),
#  (':', ':', 'O'),
#  ('Currently', 'RB', 'O'),
#  ('working', 'VBG', 'O'),
#  ('on', 'IN', 'O'),
#  ('Chat-bot', 'NNP', 'O'),
#  ('.', '.', 'O'),
#  ('Developing', 'VBG', 'O'),
#  ('Backend', 'NNP', 'O'),
#  ('Oracle', 'NNP', 'O'),
#  ('PeopleSoft', 'NNP', 'O'),
#  ('Queries', 'NNP', 'O'),
#  ('for', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('Bot', 'NNP', 'O'),
#  ('which', 'WDT', 'O'),
#  ('will', 'MD', 'O'),
#  ('be', 'VB', 'O'),
#  ('triggered', 'VBN', 'O'),
#  ('based', 'VBN', 'O'),
#  ('on', 'IN', 'O'),
#  ('given', 'VBN', 'O'),
#  ('input', 'NN', 'O'),
#  ('.', '.', 'O'),
#  ('Also', 'RB', 'O'),
#  (',', ',', 'O'),
#  ('Training', 'VBG', 'O'),
#  ('the', 'DT', 'O'),
#  ('bot', 'NN', 'O'),
#  ('for', 'IN', 'O'),
#  ('different', 'JJ', 'O'),
#  ('possible', 'JJ', 'O'),
#  ('utterances', 'NNS', 'O'),
#  ('(', '(', 'O'),
#  ('Both', 'DT', 'O'),
#  ('positive', 'JJ', 'O'),
#  ('and', 'CC', 'O'),
#  ('negative', 'JJ', 'O'),
#  (')', ')', 'O'),
#  (',', ',', 'O'),
#  ('which', 'WDT', 'O'),
#  ('will', 'MD', 'O'),
#  ('be', 'VB', 'O'),
#  ('given', 'VBN', 'O'),
#  ('as', 'IN', 'O'),
#  ('input', 'NN', 'O'),
#  ('by', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('user', 'NN', 'O'),
#  ('.', '.', 'O'),
#  ('EDUCATION', 'NNP', 'O'),
#  ('B.E', 'NNP', 'O'),
#  ('in', 'IN', 'O'),
#  ('Information', 'NNP', 'O'),
#  ('science', 'NN', 'O'),
#  ('and', 'CC', 'O'),
#  ('engineering', 'NN', 'O'),
#  ('B.v.b', 'NNP', 'O'),
#  ('college', 'NN', 'O'),
#  ('of', 'IN', 'O'),
#  ('engineering', 'NN', 'O'),
#  ('and', 'CC', 'O'),
#  ('technology', 'NN', 'O'),
#  ('-', ':', 'O'),
#  ('Hubli', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('Karnataka', 'NNP', 'O'),
#  ('August', 'NNP', 'O'),
#  ('2013', 'CD', 'O'),
#  ('to', 'TO', 'O'),
#  ('June', 'NNP', 'O'),
#  ('2017', 'CD', 'O'),
#  ('12th', 'CD', 'O'),
#  ('in', 'IN', 'O'),
#  ('Mathematics', 'NNS', 'O'),
#  ('Woodbine', 'NNP', 'O'),
#  ('modern', 'JJ', 'O'),
#  ('school', 'NN', 'O'),
#  ('April', 'NNP', 'O'),
#  ('2011', 'CD', 'O'),
#  ('to', 'TO', 'O'),
#  ('March', 'NNP', 'O'),
#  ('2013', 'CD', 'O'),
#  ('10th', 'CD', 'O'),
#  ('Kendriya', 'NNP', 'O'),
#  ('Vidyalaya', 'NNP', 'O'),
#  ('April', 'NNP', 'O'),
#  ('2001', 'CD', 'O'),
#  ('to', 'TO', 'O'),
#  ('March', 'NNP', 'O'),
#  ('2011', 'CD', 'O'),
#  ('SKILLS', 'NNP', 'O'),
#  ('C', 'NNP', 'O'),
#  ('(', '(', 'O'),
#  ('Less', 'NNP', 'O'),
#  ('than', 'IN', 'O'),
#  ('1', 'CD', 'O'),
#  ('year', 'NN', 'O'),
#  (')', ')', 'O'),
#  (',', ',', 'O'),
#  ('Database', 'NNP', 'O'),
#  ('(', '(', 'O'),
#  ('Less', 'NNP', 'O'),
#  ('than', 'IN', 'O'),
#  ('1', 'CD', 'O'),
#  ('year', 'NN', 'O'),
#  (')', ')', 'O'),
#  (',', ',', 'O'),
#  ('Database', 'NNP', 'O'),
#  ('Management', 'NNP', 'O'),
#  ('(', '(', 'O'),
#  ('Less', 'NNP', 'O'),
#  ('than', 'IN', 'O'),
#  ('1', 'CD', 'O'),
#  ('year', 'NN', 'O'),
#  (')', ')', 'O'),
#  (',', ',', 'O'),
#  ('Database', 'NNP', 'O'),
#  ('Management', 'NNP', 'O'),
#  ('System', 'NNP', 'O'),
#  ('(', '(', 'O'),
#  ('Less', 'NNP', 'O'),
#  ('than', 'IN', 'O'),
#  ('1', 'CD', 'O'),
#  ('year', 'NN', 'O'),
#  (')', ')', 'O'),
#  (',', ',', 'O'),
#  ('Java', 'NNP', 'O'),
#  ('(', '(', 'O'),
#  ('Less', 'NNP', 'O'),
#  ('than', 'IN', 'O'),
#  ('1', 'CD', 'O'),
#  ('year', 'NN', 'O'),
#  (')', ')', 'O'),
#  ('ADDITIONAL', 'NNP', 'O'),
#  ('INFORMATION', 'NNP', 'O'),
#  ('Technical', 'NNP', 'O'),
#  ('Skills', 'NNP', 'O'),
#  ('https', 'NN', 'O'),
#  (':', ':', 'O'),
#  ('//www.indeed.com/r/Abhishek-Jha/10e7a8cb732bc43a', 'JJ', 'O'),
#  ('?', '.', 'O'),
#  ('isid=rex-download', 'JJ', 'O'),
#  ('&', 'CC', 'O'),
#  ('ikw=download-top', 'JJ', 'O'),
#  ('&', 'CC', 'O'),
#  ('co=IN', 'JJ', 'O'),
#  ('•', 'NN', 'O'),
#  ('Programming', 'VBG', 'O'),
#  ('language', 'NN', 'O'),
#  (':', ':', 'O'),
#  ('C', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('C++', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('Java', 'NNP', 'O'),
#  ('•', 'NNP', 'O'),
#  ('Oracle', 'NNP', 'O'),
#  ('PeopleSoft', 'NNP', 'O'),
#  ('•', 'NNP', 'O'),
#  ('Internet', 'NNP', 'O'),
#  ('Of', 'IN', 'O'),
#  ('Things', 'NNP', 'O'),
#  ('•', 'NNP', 'O'),
#  ('Machine', 'NNP', 'O'),
#  ('Learning', 'NNP', 'O'),
#  ('•', 'NNP', 'O'),
#  ('Database', 'NNP', 'O'),
#  ('Management', 'NNP', 'O'),
#  ('System', 'NNP', 'O'),
#  ('•', 'NNP', 'O'),
#  ('Computer', 'NNP', 'O'),
#  ('Networks', 'NNP', 'O'),
#  ('•', 'NNP', 'O'),
#  ('Operating', 'NNP', 'O'),
#  ('System', 'NNP', 'O'),
#  ('worked', 'VBD', 'O'),
#  ('on', 'IN', 'O'),
#  (':', ':', 'O'),
#  ('Linux', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('Windows', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('Mac', 'NNP', 'O'),
#  ('Non', 'NNP', 'O'),
#  ('-', ':', 'O'),
#  ('Technical', 'JJ', 'O'),
#  ('Skills', 'NNP', 'O'),
#  ('•', 'NNP', 'O'),
#  ('Honest', 'NNP', 'O'),
#  ('and', 'CC', 'O'),
#  ('Hard-Working', 'NNP', 'O'),
#  ('•', 'NNP', 'O'),
#  ('Tolerant', 'NNP', 'O'),
#  ('and', 'CC', 'O'),
#  ('Flexible', 'NNP', 'O'),
#  ('to', 'TO', 'O'),
#  ('Different', 'NNP', 'O'),
#  ('Situations', 'NNP', 'O'),
#  ('•', 'NNP', 'O'),
#  ('Polite', 'NNP', 'O'),
#  ('and', 'CC', 'O'),
#  ('Calm', 'NNP', 'O'),
#  ('•', 'NNP', 'O'),
#  ('Team-Player', 'NNP', 'O')]

# %% [markdown]
# ## NLTK

# %%
sample = data[data.sentence == 'Sentence: 3']
pattern = 'NP: {<DT>?<JJ>*<NN>}'
cp = nltk.RegexpParser(pattern)
cs = cp.parse(dict(zip(sample.word, sample.pos)).items())
print(cs)
# Out:
# (S
#   They/PRP
#   marched/VBD
#   from/IN
#   the/DT
#   Houses/NNS
#   of/IN
#   (NP Parliament/NN)
#   to/TO
#   (NP a/DT rally/NN)
#   in/IN
#   Hyde/NNP
#   Park/NNP
#   ./.)

# %%
iob_tagged = tree2conlltags(cs)
pprint(iob_tagged)
pprint(sample)
# Out:
# [('Thousands', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('demonstrators', 'NNS', 'O'),
#  ('have', 'VBP', 'O'),
#  ('marched', 'VBN', 'O'),
#  ('through', 'IN', 'O'),
#  ('London', 'NNP', 'O'),
#  ('to', 'TO', 'O'),
#  ('protest', 'VB', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('war', 'NN', 'I-NP'),
#  ('in', 'IN', 'O'),
#  ('Iraq', 'NNP', 'O'),
#  ('and', 'CC', 'O'),
#  ('demand', 'VB', 'O'),
#  ('withdrawal', 'NN', 'B-NP'),
#  ('British', 'JJ', 'O'),
#  ('troops', 'NNS', 'O'),
#  ('from', 'IN', 'O'),
#  ('that', 'DT', 'B-NP'),
#  ('country', 'NN', 'I-NP'),
#  ('.', '.', 'O')]
#        sentence           word  pos    tag
# 0   Sentence: 1      Thousands  NNS      O
# 1   Sentence: 1             of   IN      O
# 2   Sentence: 1  demonstrators  NNS      O
# 3   Sentence: 1           have  VBP      O
# 4   Sentence: 1        marched  VBN      O
# 5   Sentence: 1        through   IN      O
# 6   Sentence: 1         London  NNP  B-geo
# 7   Sentence: 1             to   TO      O
# 8   Sentence: 1        protest   VB      O
# 9   Sentence: 1            the   DT      O
# 10  Sentence: 1            war   NN      O
# 11  Sentence: 1             in   IN      O
# 12  Sentence: 1           Iraq  NNP  B-geo
# 13  Sentence: 1            and   CC      O
# 14  Sentence: 1         demand   VB      O
# 15  Sentence: 1            the   DT      O
# 16  Sentence: 1     withdrawal   NN      O
# 17  Sentence: 1             of   IN      O
# 18  Sentence: 1        British   JJ  B-gpe
# 19  Sentence: 1         troops  NNS      O
# 20  Sentence: 1           from   IN      O
# 21  Sentence: 1           that   DT      O
# 22  Sentence: 1        country   NN      O
# 23  Sentence: 1              .    .      O

# %%
ne_tree = nltk.ne_chunk(list(zip(sample.word, sample.pos)))
print(ne_tree)
# Out:
# (S
#   Thousands/NNS
#   of/IN
#   demonstrators/NNS
#   have/VBP
#   marched/VBN
#   through/IN
#   (GPE London/NNP)
#   to/TO
#   protest/VB
#   the/DT
#   war/NN
#   in/IN
#   (GPE Iraq/NNP)
#   and/CC
#   demand/VB
#   the/DT
#   withdrawal/NN
#   of/IN
#   (GPE British/JJ)
#   troops/NNS
#   from/IN
#   that/DT
#   country/NN
#   ./.)

# %% [markdown]
# ## SpaCy

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
sample = data[data.sentence == 'Sentence: 8']
doc = nlp(' '.join(sample.word))
pprint([(X.text, X.label_) for X in doc.ents])
pprint([(X, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
# [('The International Atomic Energy Agency', 'ORG'),
#  ('second', 'ORDINAL'),
#  ('Vienna', 'GPE'),
#  ('Wednesday', 'DATE'),
#  ('Iran', 'GPE')]
# [(The, 'B', 'ORG'),
#  (International, 'I', 'ORG'),
#  (Atomic, 'I', 'ORG'),
#  (Energy, 'I', 'ORG'),
#  (Agency, 'I', 'ORG'),
#  (is, 'O', ''),
#  (to, 'O', ''),
#  (hold, 'O', ''),
#  (second, 'B', 'ORDINAL'),
#  (day, 'O', ''),
#  (of, 'O', ''),
#  (talks, 'O', ''),
#  (in, 'O', ''),
#  (Vienna, 'B', 'GPE'),
#  (Wednesday, 'B', 'DATE'),
#  (on, 'O', ''),
#  (how, 'O', ''),
#  (to, 'O', ''),
#  (respond, 'O', ''),
#  (to, 'O', ''),
#  (Iran, 'B', 'GPE'),
#  ('s, 'O', ''),
#  (resumption, 'O', ''),
#  (of, 'O', ''),
#  (low, 'O', ''),
#  (-, 'O', ''),
#  (level, 'O', ''),
#  (uranium, 'O', ''),
#  (conversion, 'O', ''),
#  (., 'O', '')]

# %%
displacy.render(doc, jupyter=True, style='ent')
displacy.render(doc, style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The International Atomic Energy Agency
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is to hold
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     second
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  day of talks in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vienna
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  on how to respond to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Iran
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  's resumption of low-level uranium conversion .</div></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a1d7ef6ff4264401b9496ea52b4e555e-0" class="displacy" width="3410" height="497.0" direction="ltr" style="max-width: none; height: 497.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">International</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">Atomic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">Energy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">Agency</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">hold</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">second</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">day</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">talks</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">Vienna</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">Wednesday</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">how</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">respond</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">Iran</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">resumption</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">low-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">level</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">uranium</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3290">conversion .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3290">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a1d7ef6ff4264401b9496ea52b4e555e-0-0" stroke-width="2px" d="M70,362.0 C70,122.0 520.0,122.0 520.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a1d7ef6ff4264401b9496ea52b4e555e-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,364.0 L62,352.0 78,352.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a1d7ef6ff4264401b9496ea52b4e555e-0-1" stroke-width="2px" d="M190,362.0

# %%
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in doc 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('Thousands', 'NOUN', 'thousand'),
#  ('demonstrators', 'NOUN', 'demonstrator'),
#  ('marched', 'VERB', 'march'),
#  ('London', 'PROPN', 'London'),
#  ('protest', 'VERB', 'protest'),
#  ('war', 'NOUN', 'war'),
#  ('Iraq', 'PROPN', 'Iraq'),
#  ('demand', 'VERB', 'demand'),
#  ('withdrawal', 'NOUN', 'withdrawal'),
#  ('British', 'ADJ', 'british'),
#  ('troops', 'NOUN', 'troop'),
#  ('country', 'NOUN', 'country')]
