# %%
from bs4 import BeautifulSoup
import requests, lxml, json, re, datetime
headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.69 Safari/537.36'
}

# %% [markdown]
# Reference: https://serpapi.com/blog/scrape-yahoo-finance-home-page-with-python/

# %%
url = 'https://finance.yahoo.com/'
html = requests.get(url, headers=headers)
soup = BeautifulSoup(html.text, 'lxml')

all_script_tags = soup.select('script')

# https://regex101.com/r/IJloEU/2
matched_string = ''.join(re.findall(r'root\.App\.main = (.*);\n+}\(this\)\);\n+</script>', str(all_script_tags)))
matched_string_json = json.loads(matched_string)


def yahoo_get_header_stock_data():
    for key, value in dict(matched_string_json['context']['dispatcher']['stores']['StreamDataStore']['quoteData']).items():
        symbol = value['symbol']
        exchange = value['exchange']
        full_exchange_name = value['fullExchangeName']

        try:
            short_name = value['shortName']
        except:
            short_name = 'no shorten name'

        exchange_time_zone_name = value['exchangeTimezoneName']
        regular_market_change = value['regularMarketChange']['fmt']
        regular_market_previous_close = value['regularMarketPreviousClose']['fmt']
        regular_market_price = value['regularMarketPrice']['fmt']
        regular_market_change_percent = value['regularMarketChangePercent']['fmt']
        market_state = value['marketState']
        market = value['market']
        quote_type = value['quoteType']


        print(f'Symbol: {symbol}\n'
              f'Short name: {short_name}\n'
              f'Exchange: {exchange}\n'
              f'Full exchange name: {full_exchange_name}\n'
              f'Exchange timezone: {exchange_time_zone_name}\n'
              f'Market state: {market_state}\n'
              f'Market name: {market}\n'
              f'Quote type: {quote_type}\n'
              f'Market price: {regular_market_price}\n'
              f'Market change: {regular_market_change}\n'
              f'Market % change: {regular_market_change_percent}\n'
              f'Market previous close: {regular_market_previous_close}\n')



def yahoo_get_top_news_data():
    matched_string_json_stream = matched_string_json['context']['dispatcher']['stores']['ThreeAmigosStore']['data']['ntk']['stream']

    for top_news_result_index, top_news in enumerate(matched_string_json_stream):
        teaser = top_news['editorialContent']['teaser']
        title = top_news['editorialContent']['title']

        try:
            source = top_news['editorialContent']['content']['provider']['displayName']
        except:
            source = None

        try:
            source_site_link = top_news['editorialContent']['content']['provider']['url']
        except:
            source_site_link = None

        try:
            canonical_url = top_news['editorialContent']['content']['canonicalUrl']['url']
        except:
            canonical_url = None

        try:
            canonical_url_website = top_news['editorialContent']['content']['canonicalUrl']['site']
        except:
            canonical_url_website = None

        try:
            click_through_url = top_news['editorialContent']['content']['clickThroughUrl']['url']
        except:
            click_through_url = None

        try:
            click_through_url_website = top_news['editorialContent']['content']['clickThroughUrl']['site']
        except:
            click_through_url_website = None


        print(f'News result number: {top_news_result_index}\n'
              f'Teaser: {teaser}\n'
              f'Title: {title}\n'
              f'Source: {source}\n'
              f'Source website: {source_site_link}\n'
              f'Canonical URL: {canonical_url}\n'
              f'Canonical URL source: {canonical_url_website}\n'
              f'Click through URL: {click_through_url}\n'
              f'Click through website: {click_through_url_website}\n')

        for resolution in top_news['editorialContent']['thumbnail']['resolutions']:
            thumbnail_size = resolution['tag']
            thumbnail_link = resolution['url']
            print(f'{thumbnail_size} {thumbnail_link}')


def yahoo_get_top_news_video_results():
    matched_string_json_video = matched_string_json['context']['dispatcher']['stores']['ThreeAmigosStore']['data']['videos']['stream']

    for top_news_video_index, top_news_video in enumerate(matched_string_json_video):
        video_title = top_news_video['content']['title']
        video_summary = top_news_video['content']['summary']
        video_duration_not_fixed = top_news_video['content']['duration']

        # seconds converted to minutes
        video_duration_fixed_time = datetime.timedelta(seconds=video_duration_not_fixed)
        video_publication_date = top_news_video['content']['pubDate']
        vide_provider_name = top_news_video['content']['provider']['displayName']
        video_canonical_url = top_news_video['content']['canonicalUrl']['url']
        video_click_through_url = top_news_video['content']['clickThroughUrl']['url']

        print(f'Video number: {top_news_video_index}\n'
              f'Title: {video_title}\nSummary: {video_summary}\n'
              f'Duration: {video_duration_fixed_time}\n'
              f'Publication date: {video_publication_date}\n'
              f'Provider: {vide_provider_name}\n'
              f'Canonical URL: {video_canonical_url}\n'
              f'Click through URL: {video_click_through_url}\n')

        for resolution in top_news_video['content']['thumbnail']['resolutions']:
            thumbnail_size = resolution['tag']
            thumbnail_link = resolution['url']
            print(f'{thumbnail_size} {thumbnail_link}')


def yahoo_get_multiuse_news_results():
    matched_string_json_multiuse = matched_string_json['context']['dispatcher']['stores']['ThreeAmigosStore']['data']['multiuse']['stream']

    for multiuse_index, multiuse_news in enumerate(matched_string_json_multiuse):

        multiuse_title = multiuse_news['content']['title']
        multiuse_content_type = multiuse_news['content']['contentType']
        multiuse_summary = multiuse_news['content']['summary']
        multiuse_provider_name = multiuse_news['content']['provider']['displayName']
        multiuse_provider_url = multiuse_news['content']['provider']['url']
        multiuse_canonical_url = multiuse_news['content']['canonicalUrl']['url']
        multiuse_click_through_url = multiuse_news['content']['clickThroughUrl']['url']
        
        print(f'Multiuse news number: {multiuse_index}\n'
              f'Title: {multiuse_title}\n'
              f'Content type: {multiuse_content_type}\n'
              f'Summary: {multiuse_summary}\n'
              f'Provider: {multiuse_provider_name}\n'
              f'Provider URL: {multiuse_provider_url}\n'
              f'Canonical URL: {multiuse_canonical_url}\n'
              f'Click through URL: {multiuse_click_through_url}\n')

        for resolution in multiuse_news['content']['thumbnail']['resolutions']:
            thumbnail_size = resolution['tag']
            thumbnail_link = resolution['url']
            print(f'{thumbnail_size} {thumbnail_link}')


def yahoo_get_news_results():
    for yahoo_news_index in matched_string_json['context']['dispatcher']['stores']['StreamStore']['streams']['mega.c']['data']['stream_items']:
        title = yahoo_news_index['title']
        summary = yahoo_news_index['summary']
#         news_property = yahoo_news_index['property']
        source = yahoo_news_index['publisher']
#         original_publication_url = yahoo_news_index['url']
        yahoo_url = f"https://finance.yahoo.com{yahoo_news_index['link']}"

        try:
            thumbnail_medium = yahoo_news_index['images']['img:440x246']['url']
        except:
            thumbnail_medium = None

        try:
            thumbnail_small = yahoo_news_index['images']['img:220x123']['url']
        except:
            thumbnail_small = None

        print(f'Title: {title}\n'
              f'Summary: {summary}\n'
#               f'Property: {news_property}\n'
              f'Source: {source}\n'
#               f'Original URL: {original_publication_url}\n'
              f'Yahoo URL: {yahoo_url}\n'
              f'Medium thumbnail: {thumbnail_medium}\n'
              f'Small thumbnail: {thumbnail_small}\n')

# %%
# yahoo_get_header_stock_data()
yahoo_get_top_news_data()
# yahoo_get_top_news_video_results()
# yahoo_get_multiuse_news_results()
# yahoo_get_news_results()
# Out:
# News result number: 0
# Teaser: Investors monitored upbeat economic data out of China and awaited key retail sales and earnings results out from major U.S. companies later this week
# Title: S&P 500, Dow and Nasdaq end slightly lower as investors look ahead to retail sales, Walmart earnings
# Source: Yahoo Finance
# Source website: http://finance.yahoo.com/
# Canonical URL: https://finance.yahoo.com/news/stock-market-news-live-updates-november-15-2021-121525550.html
# Canonical URL source: finance
# Click through URL: https://finance.yahoo.com/news/stock-market-news-live-updates-november-15-2021-121525550.html
# Click through website: finance
#
# original https://s.yimg.com/uu/api/res/1.2/5hqCK7lhnc1nUwf9baGs9A--~B/aD0zOTk2O3c9NTk5NTthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2021-11/9dcb6cc0-4608-11ec-bffc-40c5e6a0e6a9.cf.jpg
# 570x320 https://s.yimg.com/uu/api/res/1.2/fcyx.EVviHEshVHFqXD78Q--~B/Zmk9c3RyaW07aD0zMjA7dz01NzA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/os/creatr-uploaded-images/2021-11/9dcb6cc0-4608-11ec-bffc-40c5e6a0e6a9.cf.jpg
# 201x113 https://s.yimg.com/uu/api/res/1.2/nL32DBg2vxGK0T10TpcGtA--~B/Zmk9c3RyaW07aD0xMTM7dz0yMDE7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/os/creatr-uploaded-images/2021-11/9dcb6cc0-4608-11ec-bffc-40c5e6a0e6a9.cf.jpg
# 130x130 https://s.yimg.com/uu/api/res/1.2/rTGChroScnq4xZLmBaTuug--~B/Zmk9c3RyaW07aD0xMzA7dz0xMzA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/os/creatr-uploaded-images/2021-11/9dcb6cc0-4608-11ec-bffc-40c5e6a0e6a9.cf.jpg
# News result number: 1
# Teaser: Warren Buffett's Berkshire Hathaway Inc said on Monday it eliminated its investment in Merck & Co and reduced its stakes in Abbvie Inc and Bristol-Myers Squibb Co, as it pared its overall stock market investments.
# Title: Berkshire cuts stakes in drugmakers, invests in drug royalty company
# Source: Reuters
# Source website: http://www.reuters.com/
# Canonical URL: https://finance.yahoo.com/news/buffetts-berkshire-cuts-stakes-u-215053813.html
# Canonical URL source: finance
# Click through URL: https://finance.yahoo.com/news/buffetts-berkshire-cuts-stakes-u-215053813.html
# Click through website: finance
#
# original https://s.yimg.com/uu/api/res/1.2/5azY1WwP_Fdj0Gn1rL3Q_w--~B/aD01MzM7dz04MDA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/uu/api/res/1.2/LAsSdrtjFPxXIub5xXuBlg--~B/aD01MzM7dz04MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/reuters-finance.com/ecd0cfc7ff45fd98ef59d3506371a053.cf.jpg
# 570x320 https://s.yimg.com/uu/api/res/1.2/VDr9VhWA1Tu7lO8PgCNZYw--~B/Zmk9c3RyaW07aD0zMjA7dz01NzA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/uu/api/res/1.2/LAsSdrtjFPxXIub5xXuBlg--~B/aD01MzM7dz04MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/reuters-finance.com/ecd0cfc7ff45fd98ef59d3506371a053.cf.jpg
# 201x113 https://s.yimg.com/uu/api/res/1.2/IwUCxbP8J..xqjwrM2PBmQ--~B/Zmk9c3RyaW07aD0xMTM7dz0yMDE7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/uu/api/res/1.2/LAsSdrtjFPxXIub5xXuBlg--~B/aD01MzM7dz04MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/reuters-finance.com/ecd0cfc7ff45fd98ef59d3506371a053.cf.jpg
# 130x130 https://s.yimg.com/uu/api/res/1.2/BX2b8F57AsbsWCCjmKh29Q--~B/Zmk9c3RyaW07aD0xMzA7dz0xMzA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/uu/api/res/1.2/LAsSdrtjFPxXIub5xXuBlg--~B/aD01MzM7dz04MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/reuters-finance.com/ecd0cfc7ff45fd98ef59d3506371a053.cf.jpg
# News result number: 2
# Teaser: Renaissance Technologies, Aristides Capital and Adage Capital Partners were among large U.S. hedge funds that boosted their stake or took new positions in Tesla Inc last quarter, before a searing October rally that vaulted the company's market value above $1 trillion and a subsequent tumble this month.  Renaissance added slightly more than 610,000 shares in the company, nearly quadrupling its stake, while Adage added a new position of 42,800 shares and Aristides added a new position of 8,500 shares, according to SEC disclosures.  Overall, 211 hedge funds and asset management firms added new positions in Tesla last quarter, while 116 firms closed out of their positions in the company, according data-tracking firm WhaleWisdom.
# Title: Renaissance, other big hedge funds increase stakes in Tesla in Q3
# Source: Reuters
# Source website: http://www.reuters.com/
# Canonical URL: https://finance.yahoo.com/news/renaissance-other-big-hedge-funds-223449879.html
# Canonical URL source: finance
# Click through URL: https://finance.yahoo.com/news/renaissance-other-big-hedge-funds-223449879.html
# Click through website: finance
#
# original https://s.yimg.com/uu/api/res/1.2/kSyB6Mhcq86QKVOr6tuZEg--~B/aD01MjQ7dz04MDA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/uu/api/res/1.2/VcNDNaRqNhM41gR84zHWag--~B/aD01MjQ7dz04MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/reuters-finance.com/23d0ecd5e2cca492f5f47a68d00f6ea1.cf.jpg
# 570x320 https://s.yimg.com/uu/api/res/1.2/lh2xRlry8TWHcl97dZQpVg--~B/Zmk9c3RyaW07aD0zMjA7dz01NzA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/uu/api/res/1.2/VcNDNaRqNhM41gR84zHWag--~B/aD01MjQ7dz04MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/reuters-finance.com/23d0ecd5e2cca492f5f47a68d00f6ea1.cf.jpg
# 201x113 https://s.yimg.com/uu/api/res/1.2/zX4CMcxdEIFHPY0qDrqR9w--~B/Zmk9c3RyaW07aD0xMTM7dz0yMDE7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/uu/api/res/1.2/VcNDNaRqNhM41gR84zHWag--~B/aD01MjQ7dz04MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/reuters-finance.com/23d0ecd5e2cca492f5f47a68d00f6ea1.cf.jpg
# 130x130 https://s.yimg.com/uu/api/res/1.2/e0zcMMJiKF2Q6xQk1WVJTA--~B/Zmk9c3RyaW07aD0xMzA7dz0xMzA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/uu/api/res/1.2/VcNDNaRqNhM41gR84zHWag--~B/aD01MjQ7dz04MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/reuters-finance.com/23d0ecd5e2cca492f5f47a68d00f6ea1.cf.jpg
# News result number: 3
# Teaser: Richmond Fed President Thomas Barkin told Yahoo Finance that he expects the supply chain issues that have pushed prices higher to last "well into next year."
# Title: Fed's Barkin: Need a 'few more months' to evaluate inflation
# Source: Yahoo Finance
# Source website: http://finance.yahoo.com/
# Canonical URL: https://finance.yahoo.com/news/richmond-feds-barkin-need-a-few-more-months-to-evaluate-inflationary-pressures-222549457.html
# Canonical URL source: finance
# Click through URL: https://finance.yahoo.com/news/richmond-feds-barkin-need-a-few-more-months-to-evaluate-inflationary-pressures-222549457.html
# Click through website: finance
#
# original https://s.yimg.com/uu/api/res/1.2/kdr0zr8RYmcGmPr4cFLrUg--~B/aD0yNDYzO3c9MzUyODthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-images/2020-04/161d4480-7ea2-11ea-bf5f-42a54fcddefa.cf.jpg
# 570x320 https://s.yimg.com/uu/api/res/1.2/uMNM_dcu_BSvQXz2ypvSpw--~B/Zmk9c3RyaW07aD0zMjA7dz01NzA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/os/creatr-images/2020-04/161d4480-7ea2-11ea-bf5f-42a54fcddefa.cf.jpg
# 201x113 https://s.yimg.com/uu/api/res/1.2/Swph2QQKV87NcWnmRgHGrQ--~B/Zmk9c3RyaW07aD0xMTM7dz0yMDE7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/os/creatr-images/2020-04/161d4480-7ea2-11ea-bf5f-42a54fcddefa.cf.jpg
# 130x130 https://s.yimg.com/uu/api/res/1.2/kNqKXVmtzW.0C6vjuvdwKQ--~B/Zmk9c3RyaW07aD0xMzA7dz0xMzA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/os/creatr-images/2020-04/161d4480-7ea2-11ea-bf5f-42a54fcddefa.cf.jpg
# News result number: 4
# Teaser: While COVID-19 booster shot eligibility is continuing to expand in the U.S., not all doctors believe that’s where the focus should be in the fight against the coronavirus.
# Title: Booster shots against COVID-19 'are a bit of a distraction': Doctor
# Source: Yahoo Finance
# Source website: http://finance.yahoo.com/
# Canonical URL: https://finance.yahoo.com/news/covid-19-booster-shots-distraction-doctor-211519616.html
# Canonical URL source: finance
# Click through URL: https://finance.yahoo.com/news/covid-19-booster-shots-distraction-doctor-211519616.html
# Click through website: finance
#
# original https://s.yimg.com/uu/api/res/1.2/iqSq8JW2YTr0iLNzXpP4lw--~B/aD0xNDEwO3c9MjUwODthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2021-11/4579d2b0-465c-11ec-9f5b-0c3f34002903.cf.jpg
# 570x320 https://s.yimg.com/uu/api/res/1.2/3HVRvJg2SWQ6qzco7pYM5Q--~B/Zmk9c3RyaW07aD0zMjA7dz01NzA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/os/creatr-uploaded-images/2021-11/4579d2b0-465c-11ec-9f5b-0c3f34002903.cf.jpg
# 201x113 https://s.yimg.com/uu/api/res/1.2/nndtQ4p4soOvafkTlyzySA--~B/Zmk9c3RyaW07aD0xMTM7dz0yMDE7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/os/creatr-uploaded-images/2021-11/4579d2b0-465c-11ec-9f5b-0c3f34002903.cf.jpg
# 130x130 https://s.yimg.com/uu/api/res/1.2/z_RXJJVKCDJl.xZJkJgffQ--~B/Zmk9c3RyaW07aD0xMzA7dz0xMzA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/os/creatr-uploaded-images/2021-11/4579d2b0-465c-11ec-9f5b-0c3f34002903.cf.jpg
# News result number: 5
# Teaser: Oatly (OTLY) shares are tanking after the oat-milk producer missed revenue expectations for its latest quarter and slashed its sales guidance.
# The results were "disappointing but also transitory," Cowen senior analyst Brian Holland told Yahoo Finance Live.
# Title: Oatly drops 21% in largest 1-day decline
# Source: Yahoo Finance
# Source website: http://finance.yahoo.com/
# Canonical URL: https://finance.yahoo.com/news/oatly-leaving-revenue-on-the-table-amid-supply-crunch-analyst-202943757.html
# Canonical URL source: finance
# Click through URL: https://finance.yahoo.com/news/oatly-leaving-revenue-on-the-table-amid-supply-crunch-analyst-202943757.html
# Click through website: finance
#
# original https://s.yimg.com/uu/api/res/1.2/PMVExpT3xCFNBRSKUm1P2w--~B/aD0yMDAwO3c9MzAwMDthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2021-06/9c372290-cd32-11eb-9af7-7fe62bd98c5a.cf.jpg
# 570x320 https://s.yimg.com/uu/api/res/1.2/yzVYPlrtmmaWwMISCYYRkQ--~B/Zmk9c3RyaW07aD0zMjA7dz01NzA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/os/creatr-uploaded-images/2021-06/9c372290-cd32-11eb-9af7-7fe62bd98c5a.cf.jpg
# 201x113 https://s.yimg.com/uu/api/res/1.2/jY5cNRO06NC.hRcjKsxcTw--~B/Zmk9c3RyaW07aD0xMTM7dz0yMDE7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/os/creatr-uploaded-images/2021-06/9c372290-cd32-11eb-9af7-7fe62bd98c5a.cf.jpg
# 130x130 https://s.yimg.com/uu/api/res/1.2/.Y9Tr7nmg8ln_8Ftr5Wtww--~B/Zmk9c3RyaW07aD0xMzA7dz0xMzA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/os/creatr-uploaded-images/2021-06/9c372290-cd32-11eb-9af7-7fe62bd98c5a.cf.jpg
# News result number: 6
# Teaser: Transportation Secretary Pete Buttigieg told Yahoo Finance that the infrastructure bill will allow the US to route "new dollars through old plumbing."
# Title: Infrastructure bill will put 'new dollars through old plumbing'
# Source: Yahoo Finance
# Source website: http://finance.yahoo.com/
# Canonical URL: https://finance.yahoo.com/news/infrastructure-impact-means-routing-new-dollars-through-old-plumbing-transportation-secretary-183321083.html
# Canonical URL source: finance
# Click through URL: https://finance.yahoo.com/news/infrastructure-impact-means-routing-new-dollars-through-old-plumbing-transportation-secretary-183321083.html
# Click through website: finance
#
# original https://s.yimg.com/uu/api/res/1.2/HEBKITwtbSg4UFyz0lIfwQ--~B/aD0yMTYwO3c9MzIzMzthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2021-11/681b05b0-4642-11ec-be7f-356045975136.cf.jpg
# 570x320 https://s.yimg.com/uu/api/res/1.2/htzopooOKxlroaSpfQS2_w--~B/Zmk9c3RyaW07aD0zMjA7dz01NzA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/os/creatr-uploaded-images/2021-11/681b05b0-4642-11ec-be7f-356045975136.cf.jpg
# 201x113 https://s.yimg.com/uu/api/res/1.2/van4EhE.D9nXqjSmqUDEBg--~B/Zmk9c3RyaW07aD0xMTM7dz0yMDE7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/os/creatr-uploaded-images/2021-11/681b05b0-4642-11ec-be7f-356045975136.cf.jpg
# 130x130 https://s.yimg.com/uu/api/res/1.2/mjazHffx8Yz16wgS5CR5zg--~B/Zmk9c3RyaW07aD0xMzA7dz0xMzA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/os/creatr-uploaded-images/2021-11/681b05b0-4642-11ec-be7f-356045975136.cf.jpg

# %% [markdown]
# Reference:
#
# https://pythoncircle.com/post/678/python-script-14-scraping-news-headlines-using-python-beautifulsoup/

# %%
url='https://www.bbc.com/news'
response = requests.get(url, headers=headers)

soup = BeautifulSoup(response.text, 'html.parser')
headlines = soup.find('body').find_all('h3')
for x in headlines:
    print(x.text.strip())
# Out:
# US anger at Russian anti-satellite missile test
# US anger at Russian anti-satellite missile test
# What Biden and Xi want from virtual summit
# Jury retires in trial of US teen gunman Rittenhouse
# Greta Thunberg: ‘COP26 watered down the blah, blah, blah’
# Aww. How did Adele help a happy couple? Our timed quiz...
# Man killed in UK hospital 'terror' blast named
# Biden signs $1tn infrastructure bill into law
# Steve Bannon surrenders to face contempt charges
# US journalist Fenster freed from Myanmar jail
# Apple digital IDs come with conditions and costs
# How might decisions made at COP26 change our lives?
# Apple digital IDs come with conditions and costs
# How might decisions made at COP26 change our lives?
# Former Japanese princess begins new life in US
# Trumps selling Washington hotel, reports say
# EU to widen Belarus sanctions as border row grows
# 'Paris built the arena, Glasgow starts the race'
# Rely on wind, water and solar? These islanders show how
# COP26: The story from Glasgow in 15 pictures
# How green was the COP26 climate summit?
# Can California save itself from the flames?
# Adele on weight loss, divorce and mental health
# BBC World News TV
# BBC World Service Radio
# 'I had concerns about marriage': Malala Yousafzai
# The women of Iran's underground metal scene
# The Uyghur woman fighting to keep her culture alive
# Sheeran, BTS win but LGBT rights dominate MTV EMAs
# Paralympian on the guide dog that gave her purpose
# The robots behind the bar serving your next drink
# Why the Ethiopia conflict matters to the world
# Online hate speech rose 20% during pandemic
# A US culture war raging in Brazil
# A Nobel prize-winning economist's guide to cooking
# Internet speed seen as top homebuyer priority
# The locals helping families in Poland's no-go area
# 'I could have been a racist killer'
# ‘We tried 225 children’s homes, none would take her’
# ‘We were all soaked to the skin’ - the extraordinary cave rescue
# Lyse Doucet’s love letter to Kabul through nine treasured places
# Indian activists who changed the face of Britain
# Facebook: The true meaning of 'meta'
# Why we think only children are 'worse'
# Taiwan's acidic underwater hot springs
# An overlooked masterpiece re-discovered
# The bizarre dog breeds time forgot
# 'The experience drove me to the brink'
# A relic from an ancient supercontinent
# Kane scores four as England beat San Marino 10-0 to reach World Cup
# Scotland stun Denmark to earn home World Cup play-off semi-final
# Northern Ireland draw with Italy to send Azzurri into World Cup qualifying play-offs
# Rafiq and Hutton to give evidence to MPs at select committee hearing
# England captain Farrell and hooker George out of South Africa Test
# Rashid supports Rafiq racism allegation, which Vaughan again denies
# From nearly men to World Cup winners? Can Qatar 2022 define Southgate's England legacy?
# News daily newsletter
# Mobile app
# Get in touch
